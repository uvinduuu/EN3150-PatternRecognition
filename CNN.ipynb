# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Load and preprocess the MNIST dataset
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Normalize and reshape the input data
train_images = train_images / 255.0
test_images = test_images / 255.0
train_images = train_images.reshape(-1, 28, 28, 1)  # Add the channel dimension
test_images = test_images.reshape(-1, 28, 28, 1)

# Define the CNN model
model = keras.Sequential([
    # First Convolutional Layer with 32 filters and a 3x3 kernel
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),

    # MaxPooling layer to downsample the feature maps
    layers.MaxPooling2D((2, 2)),

    # Second Convolutional Layer with 64 filters and a 3x3 kernel
    layers.Conv2D(64, (3, 3), activation='relu'),

    # MaxPooling layer to downsample the feature maps
    layers.MaxPooling2D((2, 2)),

    # Flatten the 2D feature maps to a 1D array
    layers.Flatten(),

    # Add a dense (fully connected) layer with 128 units and ReLU activation
    layers.Dense(128, activation='relu'),

    # Add another dense layer with 64 units and ReLU activation
    layers.Dense(64, activation='relu'),

    # Add the output layer with 10 units (one for each class) and softmax activation
    layers.Dense(10, activation='softmax')
])

learning_rate = 0.00005

optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
#optimizer = keras.optimizers.SGD(learning_rate=learning_rate,momentum=0.9)
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Tuf\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\Tuf\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Tuf\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 128)               204928
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 232650 (908.79 KB)
# Trainable params: 232650 (908.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model and collect training history

history = model.fit(train_images, train_labels, epochs=10, validation_split=0.4, batch_size=1024, verbose=2)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\Tuf\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Tuf\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 36/36 - 5s - loss: 2.2581 - accuracy: 0.2748 - val_loss: 2.1909 - val_accuracy: 0.4413 - 5s/epoch - 145ms/step
# Epoch 2/10
# 36/36 - 4s - loss: 2.0965 - accuracy: 0.5020 - val_loss: 1.9542 - val_accuracy: 0.5835 - 4s/epoch - 108ms/step
# Epoch 3/10
# 36/36 - 4s - loss: 1.7816 - accuracy: 0.6430 - val_loss: 1.5515 - val_accuracy: 0.7236 - 4s/epoch - 105ms/step
# Epoch 4/10
# 36/36 - 4s - loss: 1.3479 - accuracy: 0.7511 - val_loss: 1.1088 - val_accuracy: 0.7961 - 4s/epoch - 107ms/step
# Epoch 5/10
# 36/36 - 4s - loss: 0.9587 - accuracy: 0.8099 - val_loss: 0.7826 - val_accuracy: 0.8409 - 4s/epoch - 108ms/step
# Epoch 6/10
# 36/36 - 4s - loss: 0.6994 - accuracy: 0.8489 - val_loss: 0.5883 - val_accuracy: 0.8697 - 4s/epoch - 104ms/step
# Epoch 7/10
# 36/36 - 4s - loss: 0.5445 - accuracy: 0.8739 - val_loss: 0.4727 - val_accuracy: 0.8904 - 4s/epoch - 101ms/step
# Epoch 8/10
# 36/36 - 4s - loss: 0.4509 - accuracy: 0.8892 - val_loss: 0.4028 - val_accuracy: 0.9006 - 4s/epoch - 101ms/step
# Epoch 9/10
# 36/36 - 4s - loss: 0.3919 - accuracy: 0.8994 - val_loss: 0.3558 - val_accuracy: 0.9098 - 4s/epoch - 100ms/step
# Epoch 10/10
# 36/36 - 4s - loss: 0.3501 - accuracy: 0.9074 - val_loss: 0.3228 - val_accuracy: 0.9167 - 4s/epoch - 100ms/step

# %%
import matplotlib.pyplot as plt
# Plot training, validation, and testing loss with respect to epochs
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss', linestyle='--', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='--', marker='o')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Evaluate the model on the test data and collect test loss
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_acc}")
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3145 - accuracy: 0.9215
# Test Loss: 0.3145301938056946
# Test Accuracy: 0.921500027179718
